# %%
import pandas as pd
import random

# %%
note= pd.read_csv("note.csv")

note['Note'] = note['Note'].round()
note=note[["Nom de l'etablissement","Note"]]
print(f"ce dataset a {note.shape[0]} lignes et {note.shape[1]} colonnes")
note.head(10)
# Out:
# ce dataset a 50 lignes et 2 colonnes
#      Nom de l'etablissement  Note
# 0      Hotel Ibis - Plateau   4.0
# 1               Hotel Fanon   3.0
# 2              Hotel Ivoire   4.0
# 3           Hotel Palm Club   4.0
# 4            Hotel Concorde   3.0
# 5                Hotel KONA   3.0
# 6  Hotel Residence Harmonie   3.0
# 7            Hotel des Arts   3.0
# 8                 Hotel VTR   3.0
# 9           Hotel La Source   3.0

# %%
note.to_csv("note.csv")

# %%
d= pd.read_csv("note.csv")
d
# Out:
#     Unnamed: 0                     Nom de l'etablissement  Note
# 0            0                       Hotel Ibis - Plateau   4.0
# 1            1                                Hotel Fanon   3.0
# 2            2                               Hotel Ivoire   4.0
# 3            3                            Hotel Palm Club   4.0
# 4            4                             Hotel Concorde   3.0
# 5            5                                 Hotel KONA   3.0
# 6            6                   Hotel Residence Harmonie   3.0
# 7            7                             Hotel des Arts   3.0
# 8            8                                  Hotel VTR   3.0
# 9            9                            Hotel La Source   3.0
# 10          10                               Hotel Soleil   3.0
# 11          11                              Hotel Belview   4.0
# 12          12                               Hotel Hudson   4.0
# 13          13                                 Hotel Kimi   4.0
# ...
